# %%
import numpy as np
import matplotlib.pyplot as plt

# Given data
epochs = list(range(1, 32))
box_loss = [0.5, 0.45, 0.4, 0.35, 0.3, 0.25, 0.2, 0.18, 0.16, 0.15, 0.14, 0.13, 0.12, 0.11, 0.1, 0.09, 0.08, 0.07, 0.06, 0.05, 0.045, 0.04, 0.035, 0.03, 0.025, 0.02, 0.018, 0.016, 0.015, 0.014, 0.013]
class_loss = [0.3, 0.28, 0.25, 0.22, 0.2, 0.18, 0.16, 0.14, 0.12, 0.1, 0.09, 0.08, 0.07, 0.065, 0.06, 0.055, 0.05, 0.045, 0.04, 0.035, 0.032, 0.03, 0.028, 0.026, 0.024, 0.022, 0.02, 0.018, 0.016, 0.015, 0.014]

# Define precision values in a non-uniform manner from 0.7 to 0.79
precision_values = np.array([0.7, 0.71, 0.72, 0.725, 0.73, 0.735, 0.74, 0.745, 0.75, 0.755,
                             0.76, 0.765, 0.77, 0.775, 0.78, 0.785, 0.79, 0.785, 0.78, 0.775,
                             0.77, 0.772, 0.774, 0.776, 0.778, 0.78, 0.782, 0.784, 0.786, 0.788, 0.79])

# Define recall values in a non-uniform manner from 0.7 to 0.79
recall_values = np.array([0.7, 0.705, 0.71, 0.72, 0.725, 0.73, 0.735, 0.74, 0.745, 0.75,
                          0.755, 0.76, 0.765, 0.77, 0.775, 0.78, 0.785, 0.79, 0.785, 0.78,
                          0.775, 0.77, 0.765, 0.76, 0.755, 0.75, 0.745, 0.74, 0.735, 0.73, 0.725])

# Define mAP values in a non-uniform manner from 0.7 to 0.79
mAP_values = np.array([0.7, 0.705, 0.71, 0.715, 0.72, 0.725, 0.73, 0.735, 0.74, 0.745,
                       0.75, 0.755, 0.76, 0.765, 0.77, 0.775, 0.78, 0.785, 0.79, 0.785,
                       0.78, 0.775, 0.77, 0.765, 0.76, 0.755, 0.75, 0.745, 0.74, 0.735, 0.73])

print("Precision values:", precision_values)
print("Recall values:", recall_values)
print("mAP values:", mAP_values)

# Plotting each metric separately
plt.figure(figsize=(12, 8))

# Box Loss
plt.subplot(3, 2, 1)
plt.plot(epochs, box_loss, color='blue')
plt.title('Box Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')

# Class Loss
plt.subplot(3, 2, 2)
plt.plot(epochs, class_loss, color='red')
plt.title('Class Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')

# Precision
plt.subplot(3, 2, 3)
plt.plot(epochs, precision_values, color='green')
plt.title('Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')

# Recall
plt.subplot(3, 2, 4)
plt.plot(epochs, recall_values, color='orange')
plt.title('Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')

# mAP
plt.subplot(3, 2, 5)
plt.plot(epochs, mAP_values, color='purple')
plt.title('mAP')
plt.xlabel('Epoch')
plt.ylabel('mAP')

plt.tight_layout()
plt.show()
# Out:
# Precision values: [0.7   0.71  0.72  0.725 0.73  0.735 0.74  0.745 0.75  0.755 0.76  0.765
#  0.77  0.775 0.78  0.785 0.79  0.785 0.78  0.775 0.77  0.772 0.774 0.776
#  0.778 0.78  0.782 0.784 0.786 0.788 0.79 ]
# Recall values: [0.7   0.705 0.71  0.72  0.725 0.73  0.735 0.74  0.745 0.75  0.755 0.76
#  0.765 0.77  0.775 0.78  0.785 0.79  0.785 0.78  0.775 0.77  0.765 0.76
#  0.755 0.75  0.745 0.74  0.735 0.73  0.725]
# mAP values: [0.7   0.705 0.71  0.715 0.72  0.725 0.73  0.735 0.74  0.745 0.75  0.755
#  0.76  0.765 0.77  0.775 0.78  0.785 0.79  0.785 0.78  0.775 0.77  0.765
#  0.76  0.755 0.75  0.745 0.74  0.735 0.73 ]
