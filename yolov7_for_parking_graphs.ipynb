# %%
import matplotlib.pyplot as plt

# Example data for 30 epochs
epochs = list(range(1, 31))  # Adjusted to 30 epochs

box_loss = [0.07152, 0.06726, 0.06629, 0.06523, 0.06294, 0.05958, 0.05785, 0.05488, 0.05441, 0.05189,
            0.04714, 0.04381, 0.04163, 0.04149, 0.04074, 0.03784, 0.0354, 0.03235, 0.03171, 0.02956,
            0.02873, 0.02675, 0.02623, 0.02549, 0.0249, 0.02462, 0.0245, 0.02309, 0.02337, 0.0225]

class_loss = [0.06046, 0.0697, 0.07427, 0.07628, 0.06739, 0.06877, 0.06437, 0.06431, 0.05535, 0.05111,
              0.05227, 0.05111, 0.05294, 0.05295, 0.05436, 0.05054, 0.05085, 0.048, 0.04933, 0.04797,
              0.04776, 0.04764, 0.04709, 0.04743, 0.04848, 0.0463, 0.04598, 0.04702, 0.04526, 0.0472]

precision = [0.0196, 0.0258, 0.0475, 0.0379, 0.0709, 0.724, 0.297, 0.196, 0.621, 0.546, 0.544, 0.748, 0.586,
             0.751, 0.618, 0.861, 0.849, 0.769, 0.872, 0.854, 0.774, 0.866, 0.827, 0.876, 0.802, 0.901, 0.892,
             0.867, 0.856, 0.857]

recall = [0.353, 0.293, 0.136, 0.207, 0.154, 0.252, 0.296, 0.614, 0.544, 0.58, 0.616, 0.627, 0.597, 0.63, 0.643,
          0.679, 0.679, 0.683, 0.664, 0.664, 0.682, 0.68, 0.681, 0.676, 0.672, 0.686, 0.68, 0.676, 0.668, 0.683]

mAP = [0.0225, 0.0281, 0.0224, 0.0278, 0.0391, 0.2, 0.268, 0.207, 0.505, 0.525, 0.438, 0.638, 0.572, 0.67, 0.537,
       0.708, 0.714, 0.708, 0.699, 0.718, 0.732, 0.737, 0.737, 0.735, 0.732, 0.747, 0.752, 0.752, 0.746, 0.752]

# Plotting box loss
plt.figure(figsize=(10, 6))
plt.plot(epochs, box_loss, label='Box Loss', color='blue')
plt.title('Box Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Box Loss')
plt.legend()
plt.grid(True)
plt.show()

# Plotting class loss
plt.figure(figsize=(10, 6))
plt.plot(epochs, class_loss, label='Class Loss', color='orange')
plt.title('Class Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Class Loss')
plt.legend()
plt.grid(True)
plt.show()

# Plotting precision
plt.figure(figsize=(10, 6))
plt.plot(epochs, precision, label='Precision', color='green')
plt.title('Precision vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()
plt.grid(True)
plt.show()

# Plotting recall
plt.figure(figsize=(10, 6))
plt.plot(epochs, recall, label='Recall', color='red')
plt.title('Recall vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Metrics data
epochs = list(range(1, 30))  # Corrected to 30 epochs
mAP_5 = [0.0225, 0.0281, 0.0224, 0.0278, 0.0391, 0.2, 0.268, 0.207, 0.505, 0.525,
         0.438, 0.638, 0.572, 0.67, 0.537, 0.708, 0.714, 0.708, 0.699, 0.72,
         0.718, 0.737, 0.699, 0.732, 0.747, 0.752, 0.746, 0.752]
mAP_5_95 = [0.00302, 0.00514, 0.00343, 0.00528, 0.00777, 0.0474, 0.0848, 0.054, 0.163,
            0.212, 0.212, 0.383, 0.325, 0.394, 0.28, 0.457, 0.482, 0.461, 0.485,
            0.482, 0.482, 0.531, 0.527, 0.562, 0.56, 0.553, 0.554, 0.563]

# Plotting
plt.figure(figsize=(10, 5))

# Truncate the epochs to match the length of mAP_5 and mAP_5_95
epochs = epochs[:len(mAP_5)]

plt.plot(epochs, mAP_5, label='mAP@.5')
plt.plot(epochs, mAP_5_95, label='mAP@.5:.95')
plt.title('mAP vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('mAP')
plt.legend()
plt.grid(True)

plt.show()
